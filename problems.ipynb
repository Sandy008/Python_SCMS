# %% [markdown]
# ### Level 1: Basics with Data Types & Conditionals
#
# Odd or Even:
# Write a program that takes an integer input and prints whether it is odd or even.
#
# Largest of Three:
# Ask the user to input three numbers. Print the largest using if-elif-else.
#
# Vowel or Consonant:
# Take a character input. Check if it is a vowel or consonant.

# %%
#problem 1: Odd or Even:
user_input = int(input("Enter an integer: "))
if user_input % 2 == 0:
    print(f"{user_input} is even")
else:
    print(f"{user_input} is odd")

# %%
#problem 2: print the largest number from a list of numbers
number_1 = int(input("Enter first number: "))
number_2 = int(input("Enter second number: "))  
number_3 = int(input("Enter third number: "))

if number_1 >= number_2 and number_1 >= number_3:
    largest = number_1
elif number_2 >= number_1 and number_2 >= number_3:
    largest = number_2
else:
    largest = number_3

print(f"The largest number is: {largest}")

# %%
#check the number of vowels and consonants in a string
input_string = input("Enter a string: ")
vowels = "aeiouAEIOU"
vowel_count = 0
consonant_count = 0
for char in input_string:
    if char in vowels:
        vowel_count += 1
    elif char.isalpha():
        consonant_count += 1
print(f"The given string is: {input_string}")
print(f"Number of vowels: {vowel_count}")
print(f"Number of consonants: {consonant_count}")
# Out:
# The given string is: sdfg dfghj234567 dfgh
# Number of vowels: 0
# Number of consonants: 13

# %% [markdown]
# ### Level 2: Lists & Tuples
#
# List Sum & Average:
# Given a list of numbers, calculate the sum and average without using sum() or len() (use loops).
#
# Second Largest Number:
# Find the second largest number in a list.
#
# Unique Elements:
# Given a list with duplicates, create a new list with only unique elements (do not use set).
#
# Tuple Swap:
# Given a tuple (a, b), swap the values without using a temporary variable.

# %%
#problem 4: List Sum & Average:
# nums = [10, 20, 30, 40, 50]
# total = 0
# for num in nums:
#     total += num
# average = total / len(nums)
# print(f"Sum: {total}, Average: {average}")

# take the input from the user
# nums = input("Enter a list of numbers separated by spaces: ")
# nums = list(map(int, nums.split()))

# nums = [int(x) for x in input("Enter numbers: ").split()]

nums = []
while True:
    val = input("Enter a number (or press Enter to stop): ")
    if not val:
        break
    nums.append(int(val))

 


print(f"The given list is: {nums}")
total = sum(nums)
average = total / len(nums) if nums else 0
print(f"Sum: {total}, Average: {average}")
# Out:
# The given list is: [1213, 1234, 2345, 2345]
# Sum: 7137, Average: 1784.25

# %%
list1 = [1, 2, 3, 4, 5]
print(list1)
largest = 0

for num in list1:
    if num > largest:
        largest = num

if largest:
    list1.pop(list1.index(largest))
print(list1)

largest = 0
for num in list1:
    if num > largest:
        largest = num

print(largest)
# Out:
# [1, 2, 3, 4, 5]
# [1, 2, 3, 4]
# 4

# %%
#problem 5: Second Largest Number in a List

numbers = [12, 45, 23, 67, 34, 89, 90, 11]
first_largest = second_largest = float('-inf')
for num in numbers:
    if num > first_largest:
        second_largest = first_largest
        first_largest = num
    elif num > second_largest and num != first_largest:
        second_largest = num
print(f"First Largest: {first_largest}, Second Largest: {second_largest}")
# Out:
# First Largest: 90, Second Largest: 89

# %%
#problem 6: Unique Elements in a List
elements = [1, 2, 2, 3, 4, 4, 5]
unique_elements = []
for elem in elements:
    if elem not in unique_elements:
        unique_elements.append(elem)
print(f"Unique elements: {unique_elements}")
# Out:
# Unique elements: [1, 2, 3, 4, 5]

# %%
#problem 7: Tuple swapping
tuple1 = (1, 2, 3)
tuple2 = (4, 5, 6)
print(f"Before Swapping: Tuple 1: {tuple1}, Tuple 2: {tuple2}")
tuple1, tuple2 = tuple2, tuple1
print(f"After Swapping: Tuple 1: {tuple1}, Tuple 2: {tuple2}")
# Out:
# Before Swapping: Tuple 1: (1, 2, 3), Tuple 2: (4, 5, 6)
# After Swapping: Tuple 1: (4, 5, 6), Tuple 2: (1, 2, 3)

# %% [markdown]
# ### Level 3: Dictionaries
#
# Student Grades Dictionary:
# Create a dictionary with student names as keys and marks as values. Print:
#
# The student with the highest marks.
#
# The class average.
#
# Reverse Dictionary:
# Given a dictionary {key: value}, create a new dictionary {value: key}.

# %%
# problem 8: students marks
students = {
    "Alice": 85,
    "Bob": 92,
    "Charlie": 78,
    "David": 90
}
total_marks = sum(students.values())
average_marks = total_marks / len(students)
# print(students.get('Alice'))
# highest_score = max(students.values())
# print(f"Total Marks: {total_marks}, Average Marks: {average_marks}, Highest Scorer: {students.keys({highest_score})}")
highest_scorer = max(students, key=students.get)
print(f"Total Marks: {total_marks}, Average Marks: {average_marks}, Highest Scorer: {highest_scorer}")
# Out:
# Total Marks: 345, Average Marks: 86.25, Highest Scorer: Bob

# %%
tuple2 = (4, 5, 6)
list_3 = list(tuple2)
print(list_3)
print(tuple2)
# Out:
# [4, 5, 6]
# (4, 5, 6)
# [4, 5, 7]

# %%
#problem 9: reverse the dictionary
original_dict = {'a': 1, 'b': 2, 'c': 3}
reversed_dict = {value: key for key, value in original_dict.items()}
print(f"Original Dictionary: {original_dict}")
print(f"Reversed Dictionary: {reversed_dict}")
# Out:
# Original Dictionary: {'a': 1, 'b': 2, 'c': 3}
# Reversed Dictionary: {1: 'a', 2: 'b', 3: 'c'}

# %% [markdown]
# ### Combination of List and Dict
#
# Word Frequency:
# Take a string from the user and count how many times each word appears. Store results in a dictionary.
#
# Example:
# Input: "the cat and the dog"
# Output: {'the': 2, 'cat': 1, 'and': 1, 'dog': 1}

# %%
#problem 8: word frequency in a string
text = input("Enter a string: ")
word_list = text.split()
word_freq = {}
for word in word_list:
    word = word.lower()
    if word in word_freq:
        word_freq[word] += 1
    else:
        word_freq[word] = 1
print("Word Frequency:")
for word, freq in word_freq.items():
    print(f"{word}: {freq}")

# %% [markdown]
# ## Leet code
#
# #### 1> Given an array of integers nums and an integer target, return indices of the two numbers such that they add up to target.
#
# You may assume that each input would have exactly one solution, and you may not use the same element twice.
#
# You can return the answer in any order.
#
# **Example 1:**
#
# Input: nums = [2,7,11,15,4,5], target = 9
# Output: [0,1]
# Explanation: Because nums[0] + nums[1] == 9, we return [0, 1].
# Example 2:
#
# Input: nums = [3,2,4], target = 6
# Output: [1,2]
# Example 3:
#
# Input: nums = [3,3], target = 6
# Output: [0,1]

# %%
nums = [2,7,11,15, 4, 5]
target = 9

# nums = [3,2,4]
# target = 6

nums = [3,3,4,5,6,8]
target = 6

# %%
result=[]
print(nums)
for num in nums:
    print(f"num: {num}, index: {nums.index(num)}")
    for num_2 in nums[nums.index(num)+1:]:
        print(f"  num_2: {num_2}, index: {nums.index(num_2)}")
        if(num+ num_2==target):
            result.append((nums.index(num), nums.index(num_2)))

print(result)
# Out:
# [3, 3, 4, 5, 6, 8]
# num: 3, index: 0
#   num_2: 3, index: 0
#   num_2: 4, index: 2
#   num_2: 5, index: 3
#   num_2: 6, index: 4
#   num_2: 8, index: 5
# num: 3, index: 0
#   num_2: 3, index: 0
#   num_2: 4, index: 2
#   num_2: 5, index: 3
#   num_2: 6, index: 4
#   num_2: 8, index: 5
# num: 4, index: 2
#   num_2: 5, index: 3
#   num_2: 6, index: 4
#   num_2: 8, index: 5
# num: 5, index: 3
#   num_2: 6, index: 4
#   num_2: 8, index: 5
# num: 6, index: 4
#   num_2: 8, index: 5
# num: 8, index: 5
# [(0, 0), (0, 0)]

# %%
result=[]
for index, num in enumerate(nums):
    for index_2, num_2 in enumerate(nums[index+1:]):
        if(num + num_2 == target):
            result.append((index, index + 1 + index_2))
            # result.append(index)
            # result.append(index + 1 + index_2)

print(result)
# Out:
# [(0, 1)]

# %% [markdown]
# #### Given a string s, find the length of the longest substring without duplicate characters.
#
# Input: s = "abcabcbb"
# Output: 3
# Explanation: The answer is "abc", with the length of 3. Note that "bca" and "cab" are also correct answers.
# Example 2:
#
# Input: s = "bbbbb"
# Output: 1
# Explanation: The answer is "b", with the length of 1.
# Example 3:
#
# Input: s = "pwwkew"
# Output: 3
# Explanation: The answer is "wke", with the length of 3.
# Notice that the answer must be a substring, "pwke" is a subsequence and not a substring.

# %%
string = "ababacdeaabba"

if len(string) > 0:
    maxvalue = " "
else:
    maxvalue = ""
for index, j in enumerate(string):
    longest_string = ""
    print(longest_string)
    for index2, i in enumerate(string[index:]):
        print(f"for loop {i}")
        if i not in longest_string:
            longest_string += i
            print(longest_string)
            print(len(longest_string))
            maxvalue = longest_string if len(longest_string) > len(maxvalue) else maxvalue

        else:
            print(f"{longest_string} and {maxvalue}")
            maxvalue = longest_string if len(longest_string) > len(maxvalue) else maxvalue
            print("breaking at ", i)  
            break

print(f"the longest substring is {len(maxvalue)} is {maxvalue}")
# Out:
# for loop a
# a
# 1
# for loop b
# ab
# 2
# for loop a
# ab and ab
# breaking at  a
#
# for loop b
# b
# 1
# for loop a
# ba
# 2
# for loop b
# ba and ab
# breaking at  b
#
# for loop a
# a
# 1
# for loop b
# ab
# 2
# for loop a
# ab and ab
# breaking at  a
#
# for loop b
# b
# 1
# for loop a
# ba
# 2
# for loop c
# bac
# 3
# for loop d
# bacd
# 4
# for loop e
# bacde
# 5
# for loop a
# bacde and bacde
# breaking at  a
#
# for loop a
# a
# 1
# for loop c
# ac
# 2
# for loop d
# acd
# 3
# for loop e
# acde
# 4
# for loop a
# acde and bacde
# breaking at  a
#
# for loop c
# c
# 1
# for loop d
# cd
# 2
# for loop e
# cde
# 3
# for loop a
# cdea
# 4
# for loop a
# cdea and bacde
# breaking at  a
#
# for loop d
# d
# 1
# for loop e
# de
# 2
# for loop a
# dea
# 3
# for loop a
# dea and bacde
# breaking at  a
#
# for loop e
# e
# 1
# for loop a
# ea
# 2
# for loop a
# ea and bacde
# breaking at  a
#
# for loop a
# a
# 1
# for loop a
# a and bacde
# breaking at  a
#
# for loop a
# a
# 1
# ...

# %%
def lengthOfLongestSubstring(s):
    char_set = set()
    left = 0
    max_length = 0
    print(f"The given string is: {s}")
    print(f"Detailed Steps: char_set = {char_set}")
    for right in range(len(s)):
        print(f"Step {right + 1}: {s[left:right+1]} → window: {list(s[left:right+1])}, length: {right - left + 1}")
        # Shrink window from left while duplicate exists
        while s[right] in char_set:
            print(f"Duplicate found: {s[right]}")
            char_set.remove(s[left])
            left += 1
            print(f"Window after removing duplicate: {s[left:right+1]} → window: {list(s[left:right+1])}, length: {right - left + 1}")
        
        # Add current character
        char_set.add(s[right])
        print(f"Added {s[right]} to char_set: {char_set}")
        # Update max length
        max_length = max(max_length, right - left + 1)
        print(f"Max length updated: {max_length}")
    
    return max_length

# Test
string = "ababacdeaabba"
print(lengthOfLongestSubstring(string))  # Output: 4
# Out:
# The given string is: ababacdeaabba
# Detailed Steps: char_set = set()
# Step 1: a → window: ['a'], length: 1
# Added a to char_set: {'a'}
# Max length updated: 1
# Step 2: ab → window: ['a', 'b'], length: 2
# Added b to char_set: {'b', 'a'}
# Max length updated: 2
# Step 3: aba → window: ['a', 'b', 'a'], length: 3
# Duplicate found: a
# Window after removing duplicate: ba → window: ['b', 'a'], length: 2
# Added a to char_set: {'b', 'a'}
# Max length updated: 2
# Step 4: bab → window: ['b', 'a', 'b'], length: 3
# Duplicate found: b
# Window after removing duplicate: ab → window: ['a', 'b'], length: 2
# Added b to char_set: {'b', 'a'}
# Max length updated: 2
# Step 5: aba → window: ['a', 'b', 'a'], length: 3
# Duplicate found: a
# Window after removing duplicate: ba → window: ['b', 'a'], length: 2
# Added a to char_set: {'b', 'a'}
# Max length updated: 2
# Step 6: bac → window: ['b', 'a', 'c'], length: 3
# Added c to char_set: {'b', 'c', 'a'}
# Max length updated: 3
# ...

# %% [markdown]
# ### Median of Two Sorted Arrays

# %%
list1 = [1,2]
list2 = [3, 4]
combined_list = list1 + list2
print(combined_list)
combined_list.sort()
print(combined_list)
median = len(combined_list) // 2
print(median)   
if len(combined_list) % 2 == 0:
    median_value = (combined_list[median - 1] + combined_list[median]) / 2.0
else:
    median_value = combined_list[median]
print(f"The median is: {median_value}")

# %%
def findMedianSortedArrays(nums1, nums2):
    """
    Merge two sorted arrays efficiently without extra sorting
    """
    merged = []
    i = j = 0
    
    # Merge the two sorted arrays
    while i < len(nums1) and j < len(nums2):
        if nums1[i] <= nums2[j]:
            merged.append(nums1[i])
            i += 1
        else:
            merged.append(nums2[j])
            j += 1
    
    # Add remaining elements
    while i < len(nums1):
        merged.append(nums1[i])
        i += 1
    
    while j < len(nums2):
        merged.append(nums2[j])
        j += 1
    
    # Find median
    n = len(merged)
    if n % 2 == 0:
        return (merged[n//2 - 1] + merged[n//2]) / 2.0
    else:
        return float(merged[n//2])

# Test
print(findMedianSortedArrays([1, 2], [3, 4]))  # 2.5
# Out:
# 2.5

# %% [markdown]
# ### 3Sum Closest
#
# Given an integer array nums of length n and an integer target, find three integers in nums such that the sum is closest to target.
#
# Return the sum of the three integers.
#
# You may assume that each input would have exactly one solution.
#
#
#
# Example 1:
#
# Input: nums = [-1,2,1,-4], target = 1
# Output: 2
# Explanation: The sum that is closest to the target is 2. (-1 + 2 + 1 = 2).
# Example 2:
#
# Input: nums = [0,0,0], target = 1
# Output: 0
# Explanation: The sum that is closest to the target is 0. (0 + 0 + 0 = 0).

# %%
nums = [-1, 2, 1, 3, 4, 5]
target = 1 
nums.sort()
print(f"The given list is: {nums}")
closest_sum = float('inf')

for i in range(len(nums) - 2):
    print(f"the loop is running for {len(nums) - 2} times\n")
    # print(f"i: {i}, num[i]: {nums[i]}")
    left, right = i + 1, len(nums) - 1
    # print(f"left: {left}, right: {right}")
    while left < right:
        curr_sum = nums[i] + nums[left] + nums[right]
        print(f"Current -> i: {nums[i]}, left: {left}, right: {right}")
        # If this is closer to target, update closest_sum
        print(f"target - curr_sum ::{target} - {curr_sum} = {abs(target - curr_sum)}")
        print(f"target - closest_sum ::{target} - {closest_sum} = {abs(target - closest_sum)}")
        if abs(target - curr_sum) < abs(target - closest_sum):
            closest_sum = curr_sum

        if curr_sum < target:
            print(f"curr_sum < target: {curr_sum} < {target}")
            left += 1
            print(f"New left: {left}, right: {right}")
        elif curr_sum > target:
            print(f"curr_sum > target: {curr_sum} > {target}")
            right -= 1
            print(f"New left: {left}, right: {right}\n\n")
        else:
            # Exact match found
            # return curr_sum
            print(curr_sum)
print(closest_sum)
# Out:
# The given list is: [-1, 1, 2, 3, 4, 5]
# the loop is running for 4 times
#
# Current -> i: -1, left: 1, right: 5
# target - curr_sum ::1 - 5 = 4
# target - closest_sum ::1 - inf = inf
# curr_sum > target: 5 > 1
# New left: 1, right: 4
#
#
# Current -> i: -1, left: 1, right: 4
# target - curr_sum ::1 - 4 = 3
# target - closest_sum ::1 - 5 = 4
# curr_sum > target: 4 > 1
# New left: 1, right: 3
#
#
# Current -> i: -1, left: 1, right: 3
# target - curr_sum ::1 - 3 = 2
# target - closest_sum ::1 - 4 = 3
# curr_sum > target: 3 > 1
# New left: 1, right: 2
#
#
# Current -> i: -1, left: 1, right: 2
# target - curr_sum ::1 - 2 = 1
# target - closest_sum ::1 - 3 = 2
# curr_sum > target: 2 > 1
# New left: 1, right: 1
#
#
# the loop is running for 4 times
#
# Current -> i: 1, left: 2, right: 5
# target - curr_sum ::1 - 8 = 7
# target - closest_sum ::1 - 2 = 1
# curr_sum > target: 8 > 1
# New left: 2, right: 4
#
#
# Current -> i: 1, left: 2, right: 4
# target - curr_sum ::1 - 7 = 6
# ...

# %% [markdown]
# ### Search Insert Position
#
# Given a sorted array of distinct integers and a target value, return the index if the target is found. If not, return the index where it would be if it were inserted in order.
#
# You must write an algorithm with O(log n) runtime complexity.

# %%
array = [1,3,4]
target = 5

for index, num in enumerate(array):
    if num == target:
        print(index)
        break
    elif num > target:
        print(index)
        break
    elif index == len(array) - 1:
        print(index + 1)
        break
# Out:
# 3

# %%
#solution in O(log n) time complexity
def searchInsert(nums, target):
    left, right = 0, len(nums) - 1
    while left <= right:
        mid = (left + right) // 2
        if nums[mid] == target:
            return mid
        elif nums[mid] < target:
            left = mid + 1
        else:
            right = mid - 1
    return left
print(searchInsert([1,3,5,6], 5))  # Output: 2
print(searchInsert([1,3,5,6], 2))  # Output: 1
print(searchInsert([1,3,5,6], 7))  # Output: 4
# Out:
# 2
# 1
# 2

# %% [markdown]
# ### Multiply Strings
#
# Given two non-negative integers num1 and num2 represented as strings, return the product of num1 and num2, also represented as a string.
#
# Note: You must not use any built-in BigInteger library or convert the inputs to integer directly.

# %%
num1 = str(2)
num2 = str(11)
print(num1, num2)
result = str(int(num1) * int(num2))
print(result)
type(result)
# Out:
# 2 11
# 22
# str

# %%
num1 = str(23)
num2 = str(14)
print(f"multiplying {num1} and {num2}")
def multiply(num1: str, num2: str) -> str:
    if num1 == "0" or num2 == "0":
        return "0"
    
    # Initialize result array
    res = [0] * (len(num1) + len(num2))
    print(f"Initial res array: {res}")
    # Reverse iterate
    for i in range(len(num1) - 1, -1, -1):
        print(f"i: {i}, num1[i]: {num1[i]}")
        for j in range(len(num2) - 1, -1, -1):
            print(f"  j: {j}, num2[j]: {num2[j]}")
            print(f"the equivalent numbers are: {ord(num1[i])} {(ord('0'))}, {(ord(num2[j]))} {(ord('0'))}")
            print("  Multiplying:", (ord(num1[i]) - ord('0')), "*", (ord(num2[j]) - ord('0')))
            mul = (ord(num1[i]) - ord('0')) * (ord(num2[j]) - ord('0'))
            print(f"  mul: {mul}")
            # Position in result array
            print(f"  Calculating positions: using i = {i}, j = {j}")
            pos1, pos2 = i + j, i + j + 1
            print(f"  pos1: {i} + {j} = {pos1}, pos2: {i} + {j} + 1 = {pos2}")
            total = mul + res[pos2]
            print(f"  total (mul + res[pos2:{pos2}]): {total}")
            res[pos2] = total % 10
            print(f"  Updated res[pos2: {pos2}]: {res[pos2]}")
            res[pos1] += total // 10
            print(f"  Updated res[pos1: {pos1}]: {res[pos1]}")
            print(f"  Current res array: {res}")
    print(f"Final res array before conversion: {res}")
    
    # Convert to string
    result = ''.join(map(str, res)).lstrip('0')
    print(type(result))
    return result or "0"
print(multiply(num1, num2))
# Out:
# multiplying 23 and 14
# Initial res array: [0, 0, 0, 0]
# i: 1, num1[i]: 3
#   j: 1, num2[j]: 4
# the equivalent numbers are: 51 48, 52 48
#   Multiplying: 3 * 4
#   mul: 12
#   Calculating positions: using i = 1, j = 1
#   pos1: 1 + 1 = 2, pos2: 1 + 1 + 1 = 3
#   total (mul + res[pos2:3]): 12
#   Updated res[pos2: 3]: 2
#   Updated res[pos1: 2]: 1
#   Current res array: [0, 0, 1, 2]
#   j: 0, num2[j]: 1
# the equivalent numbers are: 51 48, 49 48
#   Multiplying: 3 * 1
#   mul: 3
#   Calculating positions: using i = 1, j = 0
#   pos1: 1 + 0 = 1, pos2: 1 + 0 + 1 = 2
#   total (mul + res[pos2:2]): 4
#   Updated res[pos2: 2]: 4
#   Updated res[pos1: 1]: 0
#   Current res array: [0, 0, 4, 2]
# i: 0, num1[i]: 2
#   j: 1, num2[j]: 4
# the equivalent numbers are: 50 48, 52 48
#   Multiplying: 2 * 4
#   mul: 8
#   Calculating positions: using i = 0, j = 1
#   pos1: 0 + 1 = 1, pos2: 0 + 1 + 1 = 2
#   total (mul + res[pos2:2]): 12
#   Updated res[pos2: 2]: 2
#   Updated res[pos1: 1]: 1
# ...

# %% [markdown]
# ### Letter Combinations of a Phone Number
#
# Given a string containing digits from 2-9 inclusive, return all possible letter combinations that the number could represent. Return the answer in any order.
#
# A mapping of digits to letters (just like on the telephone buttons) is given below. Note that 1 does not map to any letters.

# %%
input_digits = "234"
print(input_digits)

phone = {
    "2": "abc",
    "3": "def",
    "4": "ghi",
    "4": "ghi",
    "5": "jkl",
    "6": "mno",
    "7": "pqrs",
    "8": "tuv",
    "9": "wxyz"
}

result = []
def backtrack(combination, next_digits):
    print(f"\ncombination: {combination}, next_digits: {next_digits}")
    if len(next_digits) == 0:
        print(f"Appending combination : {combination}")
        result.append(combination)
        print(f"Current result: {result}")
    else:
        print(f"next_digits[0]: {next_digits[0]}, phone[next_digits[0]]: {phone[next_digits[0]]}")
        for letter in phone[next_digits[0]]:
            print(f"for {letter} in {phone[next_digits[0]]}:")
            # print(f"letter: {letter}")
            # Backtrack with the next digits
            print(f"Backtracking with combination + letter: {combination} + {letter} = {combination + letter} , next_digits[1:]: {next_digits[1:]}")
            backtrack(combination + letter, next_digits[1:])
print("Starting Backtracking with empty combination and input digits")
backtrack("", input_digits)
print(result)
print(len(result))
# Out:
# 234
# Starting Backtracking with empty combination and input digits
#
# combination: , next_digits: 234
# next_digits[0]: 2, phone[next_digits[0]]: abc
# for a in abc:
# Backtracking with combination + letter:  + a = a , next_digits[1:]: 34
#
# combination: a, next_digits: 34
# next_digits[0]: 3, phone[next_digits[0]]: def
# for d in def:
# Backtracking with combination + letter: a + d = ad , next_digits[1:]: 4
#
# combination: ad, next_digits: 4
# next_digits[0]: 4, phone[next_digits[0]]: ghi
# for g in ghi:
# Backtracking with combination + letter: ad + g = adg , next_digits[1:]:
#
# combination: adg, next_digits:
# Appending combination : adg
# Current result: ['adg']
# for h in ghi:
# Backtracking with combination + letter: ad + h = adh , next_digits[1:]:
#
# combination: adh, next_digits:
# Appending combination : adh
# Current result: ['adg', 'adh']
# for i in ghi:
# Backtracking with combination + letter: ad + i = adi , next_digits[1:]:
#
# combination: adi, next_digits:
# ...

# %% [markdown]
# ### Substring with Concatenation of All Words
#
# You are given a string s and an array of strings words. All the strings of words are of the same length.
#
# A concatenated string is a string that exactly contains all the strings of any permutation of words concatenated.
#
# For example, if words = ["ab","cd","ef"], then "abcdef", "abefcd", "cdabef", "cdefab", "efabcd", and "efcdab" are all concatenated strings. "acdbef" is not a concatenated string because it is not the concatenation of any permutation of words.
# Return an array of the starting indices of all the concatenated substrings in s. You can return the answer in any order.
#
#
#
# Example 1:
#
# Input: s = "barfoothefoobarman", words = ["foo","bar"]
#
# Output: [0,9]
#
# Explanation:
#
# The substring starting at 0 is "barfoo". It is the concatenation of ["bar","foo"] which is a permutation of words.
# The substring starting at 9 is "foobar". It is the concatenation of ["foo","bar"] which is a permutation of words.
#
# Example 2:
#
# Input: s = "wordgoodgoodgoodbestword", words = ["word","good","best","word"]
#
# Output: []
#
# Explanation:
#
# There is no concatenated substring.
#
# Example 3:
#
# Input: s = "barfoofoobarthefoobarman", words = ["bar","foo","the"]
#
# Output: [6,9,12]
#
# Explanation:
#
# The substring starting at 6 is "foobarthe". It is the concatenation of ["foo","bar","the"].
# The substring starting at 9 is "barthefoo". It is the concatenation of ["bar","the","foo"].
# The substring starting at 12 is "thefoobar". It is the concatenation of ["the","foo","bar"].

# %%
word = "barfoothefoobarman"
words = ["foo","bar"]



def findSubstring(self, s, words):
    if not s or not words:
        return []
    
    word_len = len(words[0])
    print(f"word_len: {word_len}")
    num_words = len(words)
    print(f"num_words: {num_words}")
    window_len = word_len * num_words
    print(f"window_len: {window_len}")
    word_count = {}
    print(f"word_count initialized as empty dict: {word_count}")

    # Build frequency map of words
    for w in words:
        print(f"w: {w}")
        word_count[w] = word_count.get(w, 0) + 1
        print(f"word_count: {word_count}")
    n = len(s)
    res = []

    # We start scanning from each offset within a word length
    for i in range(word_len):
        left = i
        seen = {}
        count = 0

        for j in range(i, n - word_len + 1, word_len):
            word = s[j:j + word_len]
            
            # If word is part of words list
            if word in word_count:
                seen[word] = seen.get(word, 0) + 1
                count += 1
                
                # Shrink window if word frequency is too high
                while seen[word] > word_count[word]:
                    left_word = s[left:left + word_len]
                    seen[left_word] -= 1
                    left += word_len
                    count -= 1
                
                # If all words matched exactly once
                if count == num_words:
                    res.append(left)
                    # Move left to continue searching
                    left_word = s[left:left + word_len]
                    seen[left_word] -= 1
                    left += word_len
                    count -= 1
            else:
                # Reset if we hit a word not in list
                seen.clear()
                count = 0
                left = j + word_len

    return res


s = "barfoofoobarthefoobarman"
words = ["bar","foo","the"]
print(findSubstring(0, s, words))
# Out:
# word_len: 3
# num_words: 3
# window_len: 9
# word_count initialized as empty dict: {}
# w: bar
# word_count: {'bar': 1}
# w: foo
# word_count: {'bar': 1, 'foo': 1}
# w: the
# word_count: {'bar': 1, 'foo': 1, 'the': 1}
# [6, 9, 12]

# %% [markdown]
# ### String to Integer (atoi)

# %% [markdown]
# ## HW. Longest Palindromic Substring

# %%
# class Solution(object):
#     def isMatch(self, s, p):
#         """
#         :type s: str
#         :type p: str
#         :rtype: bool
#         "

string = "ababab"
pattern = input("Enter a pattern: ")

if string == pattern:
    print(True)
elif '*' in pattern:
    while pattern[:pattern.index('*')] in string:
        print("The given pattern is in the string with repetition")
        break
# '.' Matches any single character.​​​​
elif '.' in pattern:
    if len(string) == len(pattern):
        print("The given pattern is in the string with single character match")
    else:
        print("The given pattern is not in the string")

else:
    print("The given pattern is not in the string")
# Out:
# The given pattern is not in the string
